# %%
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import SystemMessagePromptTemplate

## Function To get response from LLAma 2 model

### LLama2 model

from langchain_community.llms import HuggingFaceEndpoint

# repo_id="meta-llama/Llama-2-70b-hf"
# repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
# repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1"
# repo_id = "HuggingFaceH4/zephyr-7b-beta"
# repo_id = "microsoft/Phi-3-mini-128k-instruct"
# repo_id="meta-llama/Meta-Llama-3-8B-Instruct"
# repo_id="google/gemma-2b"
# repo_id="dataeaze/dataeaze-text2sql-codellama_7b_instruct-clinton_text_to_sql_v1"
# repo_id="Qwen/Qwen2-0.5B-Instruct"

llm = HuggingFaceEndpoint(repo_id = repo_id, huggingfacehub_api_token = API_KEY, return_full_text=True)
# Out:
# /Users/sayakmisra/Projects/email_generator/venv/lib/python3.8/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/sayakmisra/Projects/email_generator/venv/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEndpoint` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEndpoint`.
#   warn_deprecated(
# ...

# %%
# query = 'Get customer records with acv more than 1000 and zapcore more than 90'
# # query = 'Hey bot, please Get customer records with acv more than 1000 and zapcore less than 90 with least bugs and max usage'
# prompt = """You are a smart Text-to-SQL profesional.
    
#     Below are sql tables schemas paired with instruction that describes a task. 
#     Using valid SQLite, write a response that appropriately completes the request for the provided table. 
#     Provide only the SQL query in the output and nothing else and Please start your answer with, ### Output: .
    
#     ### Instruction: {query}
#     ### Input: 

#     CREATE TABLE c2_health_score (
#         c2_app_id INT NOT NULL AUTO_INCREMENT,
#         FirstName VARCHAR(50) NOT NULL,
#         LastName VARCHAR(50) NOT NULL,
#         c2_email VARCHAR(100) UNIQUE NOT NULL,
#         c2_address VARCHAR(20) UNIQUE,
#         date DATE,
#         c2_acv INT,    
#         c2_zapscore INT,
#         usage_success_score INT, 
#         no_of_bugs INT, 
#         no_of_features INT, 
#         c2_type VARCHAR(100), 
#         c2zs_color_code VARCHAR(100), 
#         PRIMARY KEY (c2_app_id)
#     );
    
#     """
# prompt = prompt.format(query=query)
# response=llm(prompt)
# print(response)

# %%
concern_list = ['bad support experience','cancellation request', 'related to payment', 'authentication error', 'data mismatch in dashboard' ]
for concern in concern_list:    
    prompt = """You are a synthetic email generator.
        
        Your task is to generate short and crisp email body to a customer success manager.
        
        The email describes the concern of '{concern}' the customer faces.
        
        Please start your response with the tag : <output>  and end the generated text with </output>. 
        
        """
    prompt = prompt.format(concern=concern)
    response=llm(prompt)
    print(response)
# Out:
# You are a synthetic email generator.
#
#         Your task is to generate short and crisp email body to a customer success manager.
#
#         The email describes the concern of 'bad support experience' the customer faces.
#
#         Please start your response with the tag : <output>  and end the generated text with </output>.
#
#         ---------------------------------------------------------------------------------------------------------------
#
# <output>
#
# Dear Customer Success Manager,
#
# I hope this email finds you well. I am writing to share a concern that one of our valued customers has expressed regarding their recent support experience.
#
# [Customer's Name] mentioned that they encountered difficulties in getting their issue resolved promptly and effectively. Specifically, they felt that the support agent was not fully understanding their problem and the solutions provided did not adequately address their concerns.
#
# ...

# %%
# Out:
#   Cell In[6], line 1
#     Dear Customer Success Manager,
#          ^
# SyntaxError: invalid syntax
