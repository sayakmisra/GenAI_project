# %%
# from langchain_core.prompts import PromptTemplate
# from langchain_core.pydantic_v1 import BaseModel, Field
# from langchain_experimental.llms.ollama_functions import OllamaFunctions
# Out:
# /Users/sayakmisra/Projects/email_generator/venv/lib/python3.8/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_core.prompts import PromptTemplate
#       2 from langchain_core.pydantic_v1 import BaseModel, Field
# ----> 3 from langchain_experimental.llms.ollama_functions import OllamaFunctions
#
# ModuleNotFoundError: No module named 'langchain_experimental'

# %%
from transformers import pipeline
# sentiment_pipeline = pipeline("sentiment-analysis")
sentiment_pipeline = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
sentiment_pipeline = pipeline(model="zabiullah/autotrain-customers_email_sentiment-3449294006")

data = [''' Great work done on this''']
sentiment_pipeline(data)
# Out:
# /Users/sayakmisra/Projects/email_generator/venv/lib/python3.8/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# [{'label': 'Satisfied', 'score': 0.9995039701461792}]

# %%
email = ''' 
Sure, let's meet at 12.

Please help us with car parking:
Car No: HR98P3214

Thanks.

'''

len(email)
# Out:
# 1846

# %%
from transformers import pipeline
sentiment_task = pipeline("sentiment-analysis", model='siebert/sentiment-roberta-large-english', tokenizer='siebert/sentiment-roberta-large-english')
sentiment_task(email)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9984849095344543}]

# %%
from transformers import pipeline
sentiment_task = pipeline("sentiment-analysis", model='cardiffnlp/twitter-roberta-base-sentiment-latest', tokenizer='cardiffnlp/twitter-roberta-base-sentiment-latest')


# email = email.replace( '"', "")
print(len(email))

sentiment_task(email)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 1846
# [{'label': 'neutral', 'score': 0.6453863382339478}]

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama3:instruct", format = 'json')
prompt = """ return 'name' with  with any random name. 
        """
response=llm(prompt)
response
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 6
#       3 llm = Ollama(model="llama3:instruct", format = 'json')
#       4 prompt = """ return 'name' with  with any random name.
#       5         """
# ----> 6 response=llm(prompt)
#       7 response
#
# File ~/Projects/email_generator/venv/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/Projects/email_generator/venv/lib/python3.8/site-packages/langchain_core/language_models/llms.py:1269, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1262 if not isinstance(prompt, str):
#    1263     raise ValueError(
# ...

# %%
# Schema for structured response
from pydantic import BaseModel, Field
class Person(BaseModel):
    name: str = Field(description="The person's name", required=True)
    height: float = Field(description="The person's height", required=True)
    hair_color: str = Field(description="The person's hair color")

# %%
# Prompt template
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    """Alex is 5 feet tall. 
Claudia is 1 feet taller than Alex and jumps higher than him. 
Claudia is a brunette and Alex is blonde.

Human: {question}
AI: """
)

# %%
# %pip install -qU langchain-ollama

# %%
# Chain
from langchain_ollama import ChatOllama

llm = ChatOllama(model="phi3", format = 'json')
structured_llm = llm.with_structured_output(Person)
chain = prompt | structured_llm

# %%
alex = chain.invoke("Describe Alex")
alex
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Projects/email_generator/venv/lib/python3.8/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/Projects/email_generator/venv/lib/python3.8/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Projects/email_generator/venv/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...
